# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nltk
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from surprise.dataset import DatasetAutoFolds
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.sentiment import SentimentIntensityAnalyzer
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from torch.utils.data import Dataset, DataLoader

# %%
pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nltk
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from surprise.dataset import DatasetAutoFolds
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.sentiment import SentimentIntensityAnalyzer
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset_path = 'content/drive/MyDrive/bollywood_movies.csv'
df = pd.read_csv('/content/drive/MyDrive/bollywood_movies.csv')

# %%
df.head(100)
# Out:
#         id                       title  year  rating  \
# 0   872906                       Jawan  2023     7.3
# 1   554600    Uri: The Surgical Strike  2019     7.2
# 2   781732                      Animal  2023     7.4
# 3   975533                 The Archies  2023     7.1
# 4   734253                   Adipurush  2023     5.3
# ..     ...                         ...   ...     ...
# 95   24827  Ajab Prem Ki Ghazab Kahani  2009     6.1
# 96  658412                        Ludo  2020     7.4
# 97  802403             Ajeeb Daastaans  2021     6.5
# 98   61400                   Thank You  2011     5.3
# 99  363343                       Raees  2017     6.7
#
#                           text  user_id
# 0                        Jawan        1
# 1     Uri: The Surgical Strike        1
# 2                       Animal        1
# 3                  The Archies        1
# 4                    Adipurush        1
# ..                         ...      ...
# 95  Ajab Prem Ki Ghazab Kahani        1
# 96                        Ludo        1
# 97             Ajeeb Daastaans        1
# 98                   Thank You        1
# 99                       Raees        1
#
# [100 rows x 6 columns]

# %%
df.describe()
# Out:
#                  id         year       rating
# count  7.419000e+03  7066.000000  7419.000000
# mean   5.398327e+05  1997.956977     3.299690
# std    3.492537e+05    22.052941     3.329836
# min    4.800000e+02  1913.000000     0.000000
# 25%    2.760925e+05  1983.250000     0.000000
# 50%    4.853830e+05  2004.000000     3.500000
# 75%    8.326715e+05  2017.000000     6.200000
# max    1.218602e+06  2026.000000    10.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7419 entries, 0 to 7418
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      7419 non-null   int64
#  1   title   7419 non-null   object
#  2   year    7066 non-null   float64
#  3   rating  7419 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 232.0+ KB

# %%
df.head(3)
# Out:
#        id                     title    year  rating
# 0  872906                     Jawan  2023.0     7.3
# 1  554600  Uri: The Surgical Strike  2019.0     7.2
# 2  781732                    Animal  2023.0     7.4

# %%
df.tail(3)
# Out:
#          id               title    year  rating
# 7416  54098             Soch Lo  2010.0     5.5
# 7417  46402  Kisse Pyaar Karoon  2009.0     0.0
# 7418  21757                Toss  2009.0     0.0

# %%
df.drop_duplicates(inplace=True)

# %%
df['year'] = df['year'].fillna(df['year'].median()).astype(int)

# %%
df['year'] = df['year'].astype(int)

# %%
df['text'] = df['title']

# %%
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['text'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
reader = Reader(rating_scale=(0, 10))

# %%
df['user_id'] = 1

# %%
from surprise import Dataset
data = Dataset.load_from_df(df[['user_id', 'id', 'rating']], reader)

# %%
svd = SVD()
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
all_movie_ids = df['id'].unique()

# %%
testset = [[1, movie_id, 0] for movie_id in all_movie_ids]  # Assuming user ID 1
predictions = svd.test(testset)

# %%
predicted_ratings = [(prediction.iid, prediction.est) for prediction in predictions]
predicted_ratings.sort(key=lambda x: x[1], reverse=True)

# %%
n_recommendations = 5
collaborative_filtering_recommendations = predicted_ratings[:n_recommendations]

# %%
print("\nCollaborative Filtering Recommendations:")
for i, (movie_id, rating) in enumerate(collaborative_filtering_recommendations):
    movie_title = df[df['id'] == movie_id]['title'].values[0]
    print(f"{i + 1}. {movie_title}: Predicted Rating - {rating:.2f}")
# Out:
# Collaborative Filtering Recommendations:
# 1. Aar Paar: Predicted Rating - 9.62
# 2. Nirmal Anand Ki Puppy: Predicted Rating - 9.62
# 3. Kashmir Daily: Predicted Rating - 9.62
# 4. Khoon Ki Pukaar: Predicted Rating - 9.61
# 5. Chuskit: Predicted Rating - 9.61

# %%
def recommend(movie):
  movie_index = new_df[new_df['title']==movie].index[0]
  distances= similarity[movie_index]
  movies_list=sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]
  for i in movies_list:
   print(new_df.iloc[i[0]].title)

# %%
new_df = df[['id','title' , 'text']]

# %%
new_df['tags']= new_df['text'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-97-5a9e9429acf6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']= new_df['text'].apply(lambda x:" ".join(x))

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['text']=new_df['text'].apply(stem)
# Out:
# <ipython-input-101-8cb6a62f392e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['text']=new_df['text'].apply(stem)

# %%
new_df.iloc[1216].title
# Out:
# 'Aisha'

# %%
new_df[new_df['title']=='Jawan'].index[0]
# Out:
# 0

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('hindi.pkl','wb'))

# %%
# Out:
# Collaborative Filtering Recommendations:
# 1. Aar Paar: Predicted Rating - 9.62
# 2. Nirmal Anand Ki Puppy: Predicted Rating - 9.62
# 3. Kashmir Daily: Predicted Rating - 9.62
# 4. Khoon Ki Pukaar: Predicted Rating - 9.61
# 5. Chuskit: Predicted Rating - 9.61
#
# Top 5 Genre-Based Recommended Movies for Romance:
# 1. Untitled Sunil Pandey/Junaid Khan Supernatural Romance: Rating - 0.00
# 2. Shuddh Desi Romance: Rating - 5.70
# 3. Midnight Romance: Rating - 0.00
# 4. Romance: Rating - 0.00

# %%
recommend('Chuskis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-f5f935ba848f> in <cell line: 1>()
# ----> 1 recommend('Chuskis')
#
# NameError: name 'recommend' is not defined
