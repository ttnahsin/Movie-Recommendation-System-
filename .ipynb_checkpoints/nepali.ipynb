# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0a004d79407c> in <cell line: 12>()
#      10
#      11 from sklearn.model_selection import train_test_split
# ---> 12 from surprise.dataset import DatasetAutoFolds
#      13 from sklearn.feature_extraction.text import TfidfVectorizer
#      14 from sklearn.metrics.pairwise import linear_kernel
#
# ModuleNotFoundError: No module named 'surprise'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install scikit-surprise
# Out:
# Collecting scikit-surprise
#   Downloading scikit-surprise-1.1.3.tar.gz (771 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise) (1.11.4)
# Building wheels for collected packages: scikit-surprise
#   Building wheel for scikit-surprise (setup.py) ... done
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.3-cp310-cp310-linux_x86_64.whl size=3162667 sha256=3e188ea83f22a9209b3c10b9de0d3484aa26f26c26414a195f03ceae6f401b6b
#   Stored in directory: /root/.cache/pip/wheels/a5/ca/a8/4e28def53797fdc4363ca4af740db15a9c2f1595ebc51fb445
# Successfully built scikit-surprise
# Installing collected packages: scikit-surprise
# Successfully installed scikit-surprise-1.1.3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import nltk
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt


from sklearn.model_selection import train_test_split
from surprise.dataset import DatasetAutoFolds
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from nltk.sentiment import SentimentIntensityAnalyzer
from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from torch.utils.data import Dataset, DataLoader

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset_path = 'content/drive/MyDrive/nepali.csv'
df = pd.read_csv('/content/drive/MyDrive/nepali.csv')

# %%
df.head(100)
# Out:
#                                   imdb_url                    title    year  \
# 0    https://www.imdb.com/title/tt7229666/          Chhakka Panja 2  2017.0
# 1    https://www.imdb.com/title/tt8393764/          Chhakka Panja 3  2018.0
# 2    https://www.imdb.com/title/tt7672868/      Intu Mintu Londonma  2018.0
# 3   https://www.imdb.com/title/tt10942220/  Kabaddi Kabaddi Kabaddi  2019.0
# 4    https://www.imdb.com/title/tt8387542/                  Captain  2019.0
# ..                                     ...                      ...     ...
# 95   https://www.imdb.com/title/tt0314385/                   Mitini  2002.0
# 96   https://www.imdb.com/title/tt3552320/             Dying Candle  2016.0
# 97   https://www.imdb.com/title/tt8205082/                     Hari  2018.0
# 98   https://www.imdb.com/title/tt8282940/               Lobhi Papi  1990.0
# 99  https://www.imdb.com/title/tt10533360/                  Halkara  2020.0
#
#     runtime                   genre  rating  votes  \
# 0   138 min           Comedy, Drama     6.6  290.0
# 1       NaN                  Comedy     6.3   96.0
# 2   120 min                 Romance     7.3   71.0
# 3       NaN  Comedy, Drama, Romance     8.6    9.0
# 4       NaN            Drama, Sport     3.2   46.0
# ..      ...                     ...     ...    ...
# 95      NaN                   Drama     7.7    7.0
# 96  126 min           Drama, Family     8.8   24.0
# 97      NaN                   Drama     8.2   25.0
# 98      NaN                  Comedy     NaN    NaN
# 99  105 min                   Drama     NaN    NaN
#
#                                                  plot
# 0   Chhakka Panja 2 continues with new story of Ra...
# 1   When she learns about the worst condition of t...
# 2   When Ishan (Dhiraj Magar) and Meera (Samragyee...
# 3                                          Add a Plot
# 4   Father's dedication to guiding his son to beco...
# ..                                                ...
# 95  Best friends' journey from childhood to marriage.
# 96  A sister fights all odds to take care of her y...
# 97  Movie follows a thirty year old overly religio...
# 98  A moralistic tale of two greedy men who forsak...
# 99  An unemployed village drunk is given a respons...
#
# [100 rows x 8 columns]

# %%
df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   imdb_url  800 non-null    object
#  1   title     800 non-null    object
#  2   year      764 non-null    float64
#  3   runtime   384 non-null    object
#  4   genre     723 non-null    object
#  5   rating    259 non-null    float64
#  6   votes     259 non-null    float64
#  7   plot      800 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 50.1+ KB

# %%
df.head(3)
# Out:
#                                 imdb_url                title    year  \
# 0  https://www.imdb.com/title/tt7229666/      Chhakka Panja 2  2017.0
# 1  https://www.imdb.com/title/tt8393764/      Chhakka Panja 3  2018.0
# 2  https://www.imdb.com/title/tt7672868/  Intu Mintu Londonma  2018.0
#
#    runtime          genre  rating  votes  \
# 0  138 min  Comedy, Drama     6.6  290.0
# 1      NaN         Comedy     6.3   96.0
# 2  120 min        Romance     7.3   71.0
#
#                                                 plot
# 0  Chhakka Panja 2 continues with new story of Ra...
# 1  When she learns about the worst condition of t...
# 2  When Ishan (Dhiraj Magar) and Meera (Samragyee...

# %%
df.tail(3)
# Out:
#                                   imdb_url         title  year runtime  \
# 795  https://www.imdb.com/title/tt2144066/   Pokhara.com  2003  30 min
# 798  https://www.imdb.com/title/tt2144066/   Pokhara.com  2003     NaN
# 799  https://www.imdb.com/title/tt8103440/   Herne Katha  2018     NaN
#
#                   genre  rating  votes  plot          text  user_id
# 795             Musical     NaN    NaN     1   Pokhara.com        1
# 798             Musical     NaN    NaN     1   Pokhara.com        1
# 799  Documentary, Short     NaN    NaN     1   Herne Katha        1

# %%
df.drop_duplicates(inplace=True)

# %%
df['year'] = df['year'].fillna(df['year'].median()).astype(int)

# %%
df['year'] = df['year'].astype(int)

# %%
df['text'] = df['title']

# %%
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['text'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
reader = Reader(rating_scale=(0, 10))

# %%
df['user_id'] = 1

# %%
from surprise import Dataset
data = Dataset.load_from_df(df[['user_id', 'imdb_url', 'rating']], reader)

# %%
svd = SVD()
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
all_movie_ids = df['imdb_url'].unique()

# %%
testset = [[1, movie_id, 0] for movie_id in all_movie_ids]  # Assuming user ID 1
predictions = svd.test(testset)

# %%
predicted_ratings = [(prediction.iid, prediction.est) for prediction in predictions]
predicted_ratings.sort(key=lambda x: x[1], reverse=True)

# %%
n_recommendations = 5
collaborative_filtering_recommendations = predicted_ratings[:n_recommendations]

# %%
print("\nCollaborative Filtering Recommendations:")
for i, (movie_id, rating) in enumerate(collaborative_filtering_recommendations):
    movie_title = df[df['imdb_url'] == movie_id]['title'].values[0]
    print(f"{i + 1}. {movie_title}: Predicted Rating - {rating:.2f}")
# Out:
# Collaborative Filtering Recommendations:
# 1. Chhakka Panja 2: Predicted Rating - 10.00
# 2. Chhakka Panja 3: Predicted Rating - 10.00
# 3. Intu Mintu Londonma: Predicted Rating - 10.00
# 4. Kabaddi Kabaddi Kabaddi: Predicted Rating - 10.00
# 5. Captain: Predicted Rating - 10.00

# %%
def recommend(movie):
  movie_index = new_df[new_df['title']==movie].index[0]
  distances= similarity[movie_index]
  movies_list=sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:6]
  for i in movies_list:
   print(new_df.iloc[i[0]].title)

# %%
new_df = df[['imdb_url','title' , 'text']]

# %%
new_df['tags']= new_df['text'].apply(lambda x:" ".join(x))
# Out:
# <ipython-input-42-5a9e9429acf6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']= new_df['text'].apply(lambda x:" ".join(x))

# %%
import nltk

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y = []

    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['text']=new_df['text'].apply(stem)
# Out:
# <ipython-input-46-8cb6a62f392e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['text']=new_df['text'].apply(stem)

# %%
#new_df.iloc[imdb_url].title

# %%
new_df[new_df['title']=='Captain'].index[0]
# Out:
# 4

# %%
import pickle

# %%
pickle.dump(new_df.to_dict(),open('nepali.pkl','wb'))

# %%
# Out:
# Collaborative Filtering Recommendations:
# 1. Aar Paar: Predicted Rating - 9.62
# 2. Nirmal Anand Ki Puppy: Predicted Rating - 9.62
# 3. Kashmir Daily: Predicted Rating - 9.62
# 4. Khoon Ki Pukaar: Predicted Rating - 9.61
# 5. Chuskit: Predicted Rating - 9.61
#
# Top 5 Genre-Based Recommended Movies for Romance:
# 1. Untitled Sunil Pandey/Junaid Khan Supernatural Romance: Rating - 0.00
# 2. Shuddh Desi Romance: Rating - 5.70
# 3. Midnight Romance: Rating - 0.00
# 4. Romance: Rating - 0.00

# %%
recommend('Chuskis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-f5f935ba848f> in <cell line: 1>()
# ----> 1 recommend('Chuskis')
#
# NameError: name 'recommend' is not defined
